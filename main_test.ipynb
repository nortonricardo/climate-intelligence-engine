# %%
import pandas as pd
from pathlib import Path

PATH = Path('data/station_distances.parquet')
df = pd.read_parquet(PATH)

# %%
print(f'Shape: {df.shape}')
print(f'Index: {df.index.name}')
df.dtypes
# Out:
# Shape: (438906, 4)
# Index: from_code
# to_code                   object
# distance_km              float32
# delta_altitude_m         float32
# effective_distance_km    float32
# dtype: object

# %%
df.tail(20)
# Out:
#           to_code  distance_km  delta_altitude_m  effective_distance_km
# from_code
# S875         A119  2906.885498        304.429993            2906.887207
# S875         A102  2909.252930        156.490005            2909.253418
# S875         A226  2930.937012        335.399994            2930.938965
# S875         A125  2933.978027        228.160004            2933.978760
# S875         A117  2944.215088        307.160004            2944.216797
# S875         A227  2953.471191        328.459991            2953.472900
# S875         A215  2973.466797        317.820007            2973.468506
# S875         A126  3010.531250        280.010010            3010.532715
# S875         A138  3038.775879        183.830002            3038.776367
# S875         A249  3039.093994        324.380005            3039.095703
# S875         A251  3097.054443        320.000000            3097.055908
# S875         A244  3114.088379        256.200012            3114.089600
# ...

# %%
df.describe()
# Out:
#          distance_km  delta_altitude_m  effective_distance_km
# count  438906.000000     438906.000000          438906.000000
# mean     1460.373291        370.850464            1460.385620
# std       792.024109        294.957550             792.015442
# min         0.026699          0.000000               0.026699
# 25%       841.912048        135.119995             841.915527
# 50%      1371.017334        306.470001            1371.021606
# 75%      2009.963623        540.640015            2009.963989
# max      4183.469727       1790.380005            4183.470215

# %%
from pathlib import Path
import pandas as pd

VARIABLES = [
    'temperature',
    'humidity',
    'rainfall',
    'global_radiation',
    'pressure',
]

for var in VARIABLES:
    path = Path(f'data/{var}.parquet')
    if not path.exists():
        print(f'{var}: arquivo não encontrado — rode 1.4_clean_data.py primeiro\n')
        continue
    df = pd.read_parquet(path)
    print(f'=== {var} ({len(df):,} registros) ===')
    print(df.head(10).to_string(index=False))
    print()
# Out:
# === temperature (70,748,950 registros) ===
# code                time  measurement
# A001 2000-05-07 12:00:00         22.6
# A001 2000-05-07 13:00:00         24.2
# A001 2000-05-07 14:00:00         25.0
# A001 2000-05-07 15:00:00         26.2
# A001 2000-05-07 16:00:00         26.7
# A001 2000-05-07 17:00:00         26.6
# A001 2000-05-07 18:00:00         28.0
# A001 2000-05-07 19:00:00         26.6
# A001 2000-05-07 20:00:00         25.8
# A001 2000-05-07 21:00:00         24.1
#
# === humidity (68,917,440 registros) ===
# code                time  measurement
# A001 2000-05-07 12:00:00         61.0
# A001 2000-05-07 13:00:00         55.0
# A001 2000-05-07 14:00:00         51.0
# A001 2000-05-07 15:00:00         44.0
# A001 2000-05-07 16:00:00         46.0
# A001 2000-05-07 17:00:00         45.0
# A001 2000-05-07 18:00:00         38.0
# A001 2000-05-07 19:00:00         41.0
# A001 2000-05-07 20:00:00         44.0
# A001 2000-05-07 21:00:00         51.0
#
# ...

# %%
from pathlib import Path
import pandas as pd

for path in sorted(Path('data').glob('*_neighbors*.parquet')):
    df = pd.read_parquet(path)
    print(f'=== {path.name} ===')
    print(f'Shape  : {df.shape}')
    print(f'Colunas: {df.columns.tolist()}')
    print(f'NaN n01: {df["n01"].isna().sum():,}  ({df["n01"].isna().mean()*100:.1f}%)')
    print(f'NaN d01: {df["d01"].isna().sum():,}  ({df["d01"].isna().mean()*100:.1f}%)')
    print(f'NaN a01: {df["a01"].isna().sum():,}  ({df["a01"].isna().mean()*100:.1f}%)')
    print()
    cols_show = ['code', 'time', 'measurement', 'n01', 'n02', 'd01', 'd02', 'a01', 'a02']
    print(df[cols_show].head(10).to_string(index=False))
    print()
